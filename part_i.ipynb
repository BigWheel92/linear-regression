# %%
import pandas as pd

#reading the comma separated file
df = pd.read_csv('ex1data1.txt', header=None)
print(df)
# Out:
#           0         1
# 0    6.1101  17.59200
# 1    5.5277   9.13020
# 2    8.5186  13.66200
# 3    7.0032  11.85400
# 4    5.8598   6.82330
# ..      ...       ...
# 92   5.8707   7.20290
# 93   5.3054   1.98690
# 94   8.2934   0.14454
# 95  13.3940   9.05510
# 96   5.4369   0.61705
#
# [97 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

#plotting the data
plt.xlabel('City''s Population')
plt.ylabel('Outlet''s Profit')
# adding vertical line in data co-ordinates
plt.axvline(0, c='black', ls='--')
  
# adding horizontal line in data co-ordinates
plt.axhline(0, c='black', ls='--')
plt.scatter(df.iloc[:, 0].values, df.iloc[:, 1].values, marker="x", c='red')

plt.show()

# %%
import numpy as np
#separating dataset into X (independent variable) and Y (dependent variable)
X= df.iloc[:, 0].values
Y= df.iloc[:, 1].values
X=np.reshape(X, (X.shape[0],1))
Y=np.reshape(Y, (Y.shape[0],1))
print(X.shape)
print(Y.shape)
# Out:
# (97, 1)
# (97, 1)

# %%
from Model import LinearRegression
model=LinearRegression()
model.fit(X,Y, numOfIterations=2000, storeCosts=False)
# Out:
# Iteration No: 1. Cost: 32.072733877455676
# Iteration No: 2. Cost: 16.769642371667477
# Iteration No: 3. Cost: 10.407579751768981
# Iteration No: 4. Cost: 7.759183480302341
# Iteration No: 5. Cost: 6.653287534646751
# Iteration No: 6. Cost: 6.188105823037992
# Iteration No: 7. Cost: 5.989084519364204
# Iteration No: 8. Cost: 5.9006537729257875
# Iteration No: 9. Cost: 5.858197920163226
# Iteration No: 10. Cost: 5.834878785201405
# Iteration No: 11. Cost: 5.819548934223245
# Iteration No: 12. Cost: 5.807578027277277
# Iteration No: 13. Cost: 5.797042577385663
# Iteration No: 14. Cost: 5.787143381054757
# Iteration No: 15. Cost: 5.777548203870704
# Iteration No: 16. Cost: 5.768118767375579
# Iteration No: 17. Cost: 5.758797354060333
# Iteration No: 18. Cost: 5.749559709152846
# Iteration No: 19. Cost: 5.740395478534908
# Iteration No: 20. Cost: 5.731300083688731
# Iteration No: 21. Cost: 5.7222713469714925
# Iteration No: 22. Cost: 5.713308089921204
# ...

# %%
#plotting the data
plt.xlabel('City''s Population in 10,000s')s
plt.ylabel('Outlet''s Profit in 10,000s')
# adding vertical line in data co-ordinates
plt.axvline(0, c='black', ls='--')
  
# adding horizontal line in data co-ordinates
plt.axhline(0, c='black', ls='--')
plt.scatter(X, Y, marker="x", c='red')
b, m=model.getThetas()

#m = slope, b=intercept
plt.plot(X, m*X + b, "b-")
plt.show()
